# %%
import pandas as pd

df = pd.read_excel('success_f.xlsx', sheet_name='final')

score_data = df[df['步道評分'] == 4.5] 
name_rough_select = df[df["步道名稱"].str.contains('合歡')]


print(score_data,type)
print("-----")
print(name_rough_select,type)
# Out:
#                 步道名稱  步道評分     所在地區   縣市    鄉鎮 難度評分  難度評分數值化    步道長度  \
# 1             玉山主峰步道   4.5   南投縣信義鄉  南投縣   信義鄉    中        3  21.800
# 10           合歡石門山步道   4.5   南投縣仁愛鄉  南投縣   仁愛鄉    低        1   1.568
# 23            合歡主峰步道   4.5   南投縣仁愛鄉  南投縣   仁愛鄉    低        1   3.600
# 33             福山植物園   4.5   宜蘭縣員山鄉  宜蘭縣   員山鄉    低        1   3.010
# 172  阿里山國家森林遊樂區巨木群步道   4.5  嘉義縣阿里山鄉  嘉義縣  阿里山鄉    低        1   1.100
# 175            鹿林山步道   4.5   南投縣信義鄉  南投縣   信義鄉    低        1   5.500
# 179           合歡東峰步道   4.5   南投縣仁愛鄉  南投縣   仁愛鄉  低-中        2   2.200
# 201     祝山觀日步道(小笠原山)   4.5  嘉義縣阿里山鄉  嘉義縣  阿里山鄉    低        1   5.600
# 209            麟趾山步道   4.5   南投縣信義鄉  南投縣   信義鄉    低        1   6.700
#
#             所需時間  小時  分鐘  轉換成分鐘  造訪人次  \
# 1           2 天    0   0     48  2287
# 10         1 小時    1   0     60  8288
# 23         2 小時    2   0    120  3449
# 33         2 小時    2   0    120  3248
# 172   1 小時 50 分鐘   1  50    110  3733
# 175   2 小時 10 分鐘   2  10    130  2821
# ...

# %%
altitude_select = df[df["海拔(低)"] >2000]
altitude_title = altitude_select[["步道名稱","步道連結"]]

print(altitude_title)
print(altitude_select)
# Out:
#                步道名稱                                               步道連結
# 5             嘉明湖步道  https://hiking.biji.co/index.php?q=trail&act=d...
# 15        田寮月世界地景步道  https://hiking.biji.co/index.php?q=trail&act=d...
# 17         富陽自然生態步道  https://hiking.biji.co/index.php?q=trail&act=d...
# 19         白鷺鷥山親山步道  https://hiking.biji.co/index.php?q=trail&act=d...
# 33            福山植物園  https://hiking.biji.co/index.php?q=trail&act=d...
# 42           羊稠森林步道  https://hiking.biji.co/index.php?q=trail&act=d...
# 67     二格山登山步道(草湳線)  https://hiking.biji.co/index.php?q=trail&act=d...
# 68          大社觀音山步道  https://hiking.biji.co/index.php?q=trail&act=d...
# 84         關仔嶺大凍山步道  https://hiking.biji.co/index.php?q=trail&act=d...
# 94            大尖山步道  https://hiking.biji.co/index.php?q=trail&act=d...
# 95           大安森林公園  https://hiking.biji.co/index.php?q=trail&act=d...
# 119         八仙山主峰步道  https://hiking.biji.co/index.php?q=trail&act=d...
# ...
